# %%
import pandas as pd 
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
import numpy as np
import re
import torch
from sentence_transformers import SentenceTransformer, util

# %%
model_name = "Huffon/sentence-klue-roberta-base" 
model = SentenceTransformer(model_name)

df = pd.read_csv(r'C:\Users\USER\source\repos\NLP_Proj\NLP_Proj\embedding.csv',  encoding='utf-8-sig')
df.columns = ["index", "input", "embedding"]
df = model.encode(df['input'].tolist())
#df = df["embedding"].apply(lambda x: re.sub(r'[^\d\.\-\se]', '', x)).apply(lambda x: list(map(float, x.split())))
#df = df.apply(lambda x: np.array(x))
#df = np.stack(df.values)
# Out:
# No sentence-transformers model found with name Huffon/sentence-klue-roberta-base. Creating a new one with MEAN pooling.

# %%
def kmeans_SSE(X):
    sse = []
    for k in range(2, 100):
        kmeans = KMeans(n_clusters=k, random_state=0)
        kmeans.fit(X)
        sse.append(kmeans.inertia_)
    return sse

def kmeans_Silhouette(X):
    silhouette = []
    for k in range(2, 100):
        kmeans = KMeans(n_clusters=k, random_state=0)
        kmeans.fit(X)
        score = silhouette_score(X, kmeans.labels_)
        silhouette.append(score)
    return silhouette

# %%
import umap

reducer = umap.UMAP(
    n_neighbors=25,
    min_dist=0.01,
    n_components=4,
    random_state=43)
df = reducer.fit_transform(df)
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\umap\umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from sklearn.decomposition import PCA


# PCA를 사용하여 2차원으로 차원 축소
pca = PCA(n_components=2)
pcav = pca.fit_transform(df)

# %%
sse = kmeans_SSE(df)
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
silh = kmeans_Silhouette(df)
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.plot(range(2, 100), sse, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.show()

# %%
plt.plot(range(2, 100), silh, marker='o')
plt.xlabel('Number of Cluster')
plt.ylabel('silhouette_score')
plt.show()

# %%
#silh = [(i + 2, val) for i , val in enumerate(silh) if i < 15]
#silh = sorted(silh, key=lambda x: x[1], reverse=True)
for s in silh:
    print(s)
# Out:
# (16, (16, 0.36307412))
# (15, (15, 0.3600834))
# (14, (14, 0.35961378))
# (13, (13, 0.3646873))
# (12, (12, 0.3611362))
# (11, (11, 0.3580365))
# (10, (10, 0.35903782))
# (9, (9, 0.365198))
# (8, (8, 0.35399628))
# (7, (7, 0.34439993))
# (6, (6, 0.35269004))
# (5, (5, 0.36123914))
# (4, (4, 0.33467427))
# (3, (3, 0.32566914))
# (2, (2, 0.29129773))

# %%
from sklearn.decomposition import PCA

data = df

# PCA를 사용하여 2차원으로 차원 축소
pca = PCA(n_components=2)
transformed_data = pca.fit_transform(data)

# 시각화
plt.figure(figsize=(8, 6))
plt.scatter(transformed_data[:, 0], transformed_data[:, 1])
plt.title('Visualization of Data using PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

kmeans = KMeans(n_clusters=9)  # 클러스터 개수 설정
kmeans.fit(data)

# 군집 중심 확인
centroids = kmeans.cluster_centers_
print("Cluster Centers:")
print(centroids)

# 군집 할당 확인
labels = kmeans.labels_
print("Cluster Labels:")
print(labels)

# 시각화
plt.figure(figsize=(8, 6))

# 데이터 포인트를 그립니다.
sns.scatterplot(x=data[:, 0], y=data[:, 1], hue=labels, palette='viridis', s=100, alpha=0.8)

# 중심점을 그립니다.
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', s=200, color='red')

plt.title('K-means Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Centers:
# [[ 1.3987358   2.2884057   1.0093045   5.7900887 ]
#  [ 7.904518    8.95127     6.036821    7.3570642 ]
#  [-1.2683473   6.698063    5.977336    3.7144737 ]
#  [ 9.227869    2.7738476   5.9402037   3.78448   ]
#  [-0.20857239  0.96327114  5.77517     7.5271025 ]
#  [ 2.6763241   8.230705    0.4940338   4.2647157 ]
#  [ 3.3732045  11.187847    5.6843853   3.411234  ]
#  [ 5.3506165  -0.98949957  4.6443706   3.2791815 ]
#  [ 7.5151668   4.388546    0.7895725   5.710619  ]]
# Cluster Labels:
# [2 5 1 ... 1 5 1]

# %%
print(kmeans.labels_)
# Out:
# [2 5 1 ... 1 5 1]

# %%
df3 = pd.read_csv(r'C:\Users\USER\source\repos\NLP_Proj\NLP_Proj\embedding.csv',  encoding='utf-8-sig')
df3.columns = ["index", "input", "embedding"]

ndf = pd.concat([pd.DataFrame(df3['input']),pd.DataFrame(kmeans.labels_)], axis = 1)
ndf.columns = ['sen' , 'lab']
print(ndf)
# Out:
#                                                      sen  lab
# 0      전정대 3학년 되는 학생인데요전정대 3학년 되는 학생인데요최근 앱개발에 관심이 생겨...    2
# 1      혹시 컴활에 대해 물어보고 싶은분 물어보세요!혹시 컴활에 대해 물어보고 싶은분 물어...    5
# 2                                공설입 지원금공설입 지원금언제들어오냐...    1
# 3      나 너무 배고파 치킨 추천좀!!!나 너무 배고파 치킨 추천좀!!!메뉴 이름도 알려줘!!!    3
# 4      50대 여성분한테 작별선물 뭐가 좋을까50대 여성분한테 작별선물 뭐가 좋을까같이 일...    1
# ...                                                  ...  ...
# 14995                           학교앞디델리학교앞디델리이제부터 밤까지하신대여    6
# 14996                                 링크드리스트링크드리스트쌉어렵고요~    1
# 14997    파이썬 질문파이썬 질문x가 정의되어있지않다고 오류가 떠요 ㅠ 어떻게 고쳐야할까요..?    1
# 14998  산학연계 sw 프로젝트 같은 하실 소융대 학우분들 찾습니다!!산학연계 sw 프로젝트...    5
# 14999                    임티 원래 2500맞지?임티 원래 2500맞지?맞는거지?    1
#
# [15000 rows x 2 columns]

# %%
from konlpy.tag import Okt
import csv

def return_df(x):
    with open(r"C:\Users\USER\Desktop\구글ML 부캠\NLP_Proj\Crap Post Detector_NLP_Proj\corpus\stopword.txt", 'r', encoding = 'utf-8-sig') as f:
         stopwords = [word for sublist in csv.reader(f) for word in sublist]
        
    df_val = {}
    okt = Okt()
    for sen in x:
        word = []
        nouns =  okt.nouns(sen)
        nouns = list(filter(lambda noun : noun not in stopwords and len(noun) > 1, nouns))
        for noun in nouns:
            if noun in word: continue
            if noun in df_val.keys():
                df_val[noun] = df_val[noun] + 1
            else:
                df_val[noun] = 1
            word.append(noun)
    return df_val

# %%
def return_tf(x):
    with open(r"C:\Users\USER\Desktop\구글ML 부캠\NLP_Proj\Crap Post Detector_NLP_Proj\corpus\stopword.txt", 'r', encoding = 'utf-8-sig') as f:
         stopwords = [word for sublist in csv.reader(f) for word in sublist]
        
    tf_val = {}
    okt = Okt()
    for sen in x:
        nouns =  okt.nouns(sen)
        nouns = list(filter(lambda noun : noun not in stopwords and len(noun) > 1, nouns))
        for noun in nouns:
            if noun in tf_val.keys():
                tf_val[noun] += 1
            else:
                tf_val[noun] = 1
    return tf_val

# %%
def return_tfidf(x, y, length):
    tfidf_val = {}
    for key, val in x.items():
        tfidf_val[key] = val * np.log(length / (y[key] * 10 + 1))
    return tfidf_val

# %%
df_cnt = return_df(ndf['sen'])
print(df_cnt)
# Out:
# {'전정': 112, '학년': 463, '학생': 154, '최근': 30, '개발': 35, '관심': 52, '반도체': 16, '관련': 149, '전공': 322, '필요': 27, '부서': 5, '직업': 12, '분야': 14, '생각': 416, '컴활': 40, '대해': 57, '공설': 30, '원금': 18, '치킨': 21, '추천': 313, '메뉴': 19, '이름': 89, '여성': 18, '작별': 1, '선물': 39, '부채': 2, '자취': 94, '간단': 3, '삼겹살': 4, '정식': 4, '행복': 11, '문과': 77, '가치관': 1, '사회': 81, '공부': 407, '운영': 35, '이과': 32, '세상': 25, '발전': 5, '지나': 11, '우리나라': 30, '기술': 29, '인간': 81, '채널': 5, '복면': 1, '소찬휘': 1, '사람': 1043, '머리뼈': 1, '머생': 1, '말좀': 3, '노트북': 122, '고민': 109, '학교': 934, '근처': 125, '배달': 11, '배민': 3, '기요': 2, '크게': 36, '개성': 1, '소개': 20, '가난뱅이': 1, '한부모': 1, '가정': 20, '성적': 129, '증명서': 39, '홈페이지': 75, '대응': 7, '교비': 14, '실화': 53, '선배': 190, '교수': 1554, '민소': 6, '가요': 554, '수업': 730, '스타일': 12, '신지': 3, '얼핏': 1, '듣기': 48, '김민': 5, '느낌': 71, '던데': 49, '족보': 72, '존재': 29, '하나요': 226, '월반': 10, '복학': 105, '예정': 37, '독학': 18, '커버': 14, '광운대': 307, '생체': 2, '정도': 258, '중상': 1, '연애': 25, '등록금': 175, '납부': 35, '명세서': 1, '군대': 108, '모병제': 1, '미군': 1, '대우': 3, '모이': 3, '나라': 39, '입장': 13, '남자': 125, '노예': 4, '착취': 5, '가장': 35, '정답': 11, '뭐임': 35, '목소리': 32, '오해': 7, '그냥': 492, '불만': 9, '예비군': 16, '작년': 59, '전역': 28, '유캠': 68, '등록': 34, '훈련': 8, '공문': 1, '문자': 87, '시기': 11, '공무원': 27, '과목': 418, '과학': 36, '진짜': 571, '설포카': 1, '대학원': 26, '학번': 93, '학기': 576, '오늘': 409, '신문사': 65, '행동': 25, '업보': 2, '컨디션': 1, '아침': 49, '당일': 14, '파토': 1, '내기': 13, '분위기': 26, '걱정': 68, '휴학': 150, '화도': 25, '장학금': 123, '신청': 377, '졸업식': 24, '사항': 87, '안보': 45, '머슬': 1, '머슬머슬': 1, '머슬근뉴키': 1, '기계': 16, '교환학생': 26, '학점': 313, '제한': 30, '곳도': 7, '뉴스': 28, '본문': 10, '내용': 128, '공란': 3, '수정': 31, '해도': 101, '권한': 6, '시벌': 4, '전과': 59, '기간': 250, '저번': 67, '학칙': 1, '기숙사': 141, '절차': 11, '황혼': 2, '어둔운': 1, '봄밤봄밤': 1, '한지민': 1, '볼라': 7, '정해': 12, '내년': 19, '졸업': 118, '학과': 115, '별로': 63, '진행': 72, '일본': 26, '노래': 57, '켄지': 1, '레몬': 5, '가수': 2, '씨발': 12, '공익': 11, '디스크': 3, '신분': 193, '질문': 360, '문제': 339, '오른쪽': 9, '다리': 13, '저리': 5, '허리': 10, '통증': 3, '가능성': 28, '머슬톡': 8, '지금': 553, '공대': 47, '과잠': 15, '시작': 150, '악몽': 1, '새내기': 178, '시간표': 114, '교차': 6, '가모': 2, '영어': 174, '발음': 6, '머리': 66, '드하': 3, '중도': 38, '부실': 3, '사임': 2, '바닥': 14, '알바': 145, '구한': 3, '흑우': 6, '조언': 37, '해주': 17, '공사': 17, '엘베': 4, '화장실': 24, '거기': 56, '계속': 196, '헬창형들헬': 1, '창형': 1, '선후': 3, '헬스': 18, '멸치': 9, '수준': 47, '생활': 134, '요즘': 142, '다시': 186, '예전': 49, '금방': 6, '원래': 166, '기억': 39, '건가': 359, '착각': 6, '세탁기': 5, '고장': 9, '면세': 1, '입자': 2, '배수': 2, '대서': 3, '뚜껑': 2, '탈수': 1, '서비스': 15, '센터': 18, '다다다': 1, '점점': 25, '능력': 11, '떼법': 1, '정규직': 5, '릴펌': 1, '츄천해': 1, '스트릿': 1, '밤샛다': 1, '자퇴': 13, '싸인': 4, '방학': 50, '출근': 11, '장님': 8, '메일': 167, '미리': 56, '공학': 138, '인증': 77, '교양': 195, '부분': 84, '전화': 73, '미니스톱': 1, '새우': 3, '스틱': 2, '가위바위보': 3, '때내': 1, '확률': 20, '퍼잖아': 1, '승부': 3, '날때': 1, '친구': 194, '자꾸': 63, '광운대역': 29, '패스트푸드': 3, '보고': 194, '개열': 1, '애쉬': 2, '아일랜드': 1, '굳이': 29, '이드': 5, '금딸': 1, '취업': 96, '체감': 3, '비유': 2, '소득': 30, '분위': 24, '기준': 76, '아버지': 14, '퇴직': 4, '집안': 12, '도대체': 49, '집값': 3, '때문': 123, '이징': 1, '묵돈': 1, '학자금대출': 6, '부모님': 48, '차도': 4, '소나타': 1, '국장': 40, '정말': 84, '약속': 8, '해당': 30, '군의관': 1, '훠훠훠': 1, '병쉰': 1, '공시': 6, '봅니꽈': 1, '훠훠': 3, '유투브': 10, '지인': 12, '도움': 56, '국가': 60, '근로': 54, '교내': 35, '뽕팡하예프': 1, '이제': 174, '수만휘': 2, '슴돠': 2, '주워왔슴돠': 1, '언어': 32, '표현': 20, '갑자기': 143, '개발자': 3, '달라': 42, '포인터': 2, '학점교류': 10, '균형': 10, '꼭무': 1, '소음': 3, '보드': 23, '마우스': 17, '제출': 235, '졸업생': 13, '이용': 60, '내야': 24, '과기대': 6, '아무': 52, '쓰레기': 33, '심리': 41, '엄마': 27, '아빠': 17, '교육': 35, '에타': 150, '업데이트': 10, '업뎃되': 1, '아시': 184, '동생': 23, '산업': 22, '가나': 19, '두루': 7, '유형': 19, '제외': 35, '중복': 7, '가유': 4, '수강신청': 326, '자료': 142, '연말정산': 2, '조교': 42, '힙합': 6, '동아리': 139, '묶여서': 1, '만하': 10, '푸드코트': 4, '함지': 2, '마루': 3, '팩트': 16, '임광': 2, '국숭곽대': 1, '숭곽': 1, '애들국숭곽': 1, '메인': 4, '잡과': 1, '입결': 9, '광운': 126, '선택': 55, '사실': 77, '도서관': 150, '가능': 111, '영상': 81, '기본': 30, '동영상': 17, '소리': 106, '녹음': 15 ...

# %%
df_cnt = sorted(df_cnt.items(), key=lambda x: x[1], reverse=True)
print(df_cnt)
# Out:
# [('교수', 1554), ('사람', 1043), ('과제', 976), ('강의', 950), ('학교', 934), ('수업', 730), ('학기', 576), ('진짜', 571), ('가요', 554), ('지금', 553), ('그냥', 492), ('시험', 487), ('학년', 463), ('인강', 421), ('과목', 418), ('생각', 416), ('오늘', 409), ('공부', 407), ('실험', 383), ('신청', 377), ('질문', 360), ('건가', 359), ('공지', 343), ('문제', 339), ('대학', 336), ('수강신청', 326), ('전공', 322), ('추천', 313), ('학점', 313), ('광운대', 307), ('이해', 274), ('정도', 258), ('중간고사', 252), ('기간', 250), ('정정', 240), ('제출', 235), ('수학', 230), ('하나요', 226), ('수강', 214), ('쪽지', 206), ('계속', 196), ('교양', 195), ('친구', 194), ('보고', 194), ('신분', 193), ('온라인', 193), ('교재', 193), ('레포트', 193), ('선배', 190), ('대면', 187), ('다시', 186), ('아시', 184), ('물리', 184), ('한번', 181), ('새내기', 178), ('등록금', 175), ('개강', 175), ('영어', 174), ('이제', 174), ('메일', 167), ('원래', 166), ('제발', 160), ('내일', 158), ('대체', 156), ('학생', 154), ('휴학', 150), ('시작', 150), ('에타', 150), ('도서관', 150), ('관련', 149), ('알바', 145), ('갑자기', 143), ('요즘', 142), ('자료', 142), ('기숙사', 141), ('동아리', 139), ('공학', 138), ('보통', 135), ('생활', 134), ('중간', 134), ('처음', 133), ('확인', 130), ('성적', 129), ('내용', 128), ('광운', 126), ('근처', 125), ('남자', 125), ('준비', 124), ('장학금', 123), ('때문', 123), ('노트북', 122), ('주차', 122), ('방법', 119), ('졸업', 118), ('연기', 118), ('계획', 117), ('학과', 115), ('시간표', 114), ('전정', 112), ('가능', 111), ('고민', 109), ('군대', 108), ('뭔가', 108), ('소리', 106), ('복학', 105), ('재수강', 104), ('경영', 104), ('사진', 103), ('하루', 102), ('해도', 101), ('사용', 101), ('어케', 99), ('기초', 98), ('청원', 98), ('프로그램', 97), ('취업', 96), ('출석', 96), ('존나', 95), ('자취', 94), ('컴공', 94), ('서울', 94), ('사고', 94), ('학번', 93), ('계절', 93), ('퀴즈', 92), ('경영학', 91), ('전자기학', 91), ('주변', 91), ('얘기', 91), ('이름', 89), ('전자회로', 88), ('문자', 87), ('사항', 87), ('댓글', 87), ('실습', 87), ('부분', 84), ('정말', 84), ('이유', 84), ('점수', 84), ('인정', 83), ('여자', 83), ('작성', 83), ('그거', 82), ('사회', 81), ('인간', 81), ('영상', 81), ('인터넷', 81), ('이면', 81), ('처리', 81), ('토익', 80), ('솔루션', 80), ('추가', 79), ('진자', 78), ('연락', 78), ('문과', 77), ('인증', 77), ('사실', 77), ('프로그래밍', 77), ('복전', 77), ('열람', 77), ('기준', 76), ('학부', 76), ('아이패드', 76), ('홈페이지', 75), ('파일', 75), ('경우', 75), ('누가', 75), ('나중', 74), ('오류', 74), ('컴퓨터', 74), ('전화', 73), ('경제', 73), ('현재', 73), ('족보', 72), ('진행', 72), ('상황', 72), ('대수', 72), ('느낌', 71), ('가격', 71), ('가지', 71), ('그대로', 71), ('정보', 71), ('회로이론', 70), ('환불', 70), ('화학', 69), ('전체', 69), ('유캠', 68), ('걱정', 68), ('아예', 68), ('보신', 68), ('포함', 68), ('자리', 68), ('오프라인', 68), ('저번', 67), ('머리', 66), ('결과', 66), ('프로', 66), ('신문사', 65), ('지원', 65), ('연습', 65), ('발표', 65), ('구해', 65), ('말씀', 64), ('카페', 64), ('다운', 64), ('이건', 64), ('별로', 63), ('자꾸', 63), ('차이', 63), ('운체', 63), ('페가수스', 63), ('제대로', 62), ('취소', 62), ('일반', 61), ('영화', 61), ('국가', 60), ('이용', 60), ('운동', 60), ('작년', 59), ('전과', 59), ('게시판', 59), ('모든', 59), ('무조건', 58), ('대해', 57), ('노래', 57), ('범위', 57), ('제일', 57), ('설문조사', 57), ('지각', 57), ('거기', 56), ('미리', 56), ('도움', 56), ('공수', 56), ('게임', 56), ('인생', 56), ('방금', 56), ('전략', 56), ('선택', 55), ('관리', 55), ('가면', 55), ('새끼', 55), ('필기', 55), ('문화', 55), ('대한', 55), ('근로', 54), ('참고', 54), ('저녁', 54), ('이메일', 54), ('포기', 54), ('드랍', 54), ('학습', 54), ('실화', 53), ('벌써', 53), ('검색', 53), ('오픈', 53), ('클라스', 53), ('모바일', 53), ('기말고사', 53), ('관심', 52), ('아무', 52), ('거리', 52), ('예술', 52), ('필수', 52), ('반대', 52), ('설계', 52), ('정상', 52), ('의견', 52), ('만석', 52), ('코딩', 51), ('소프트', 51), ('올해', 51), ('된거', 51), ('설명', 51), ('예비', 51), ('주말', 51), ('방학', 50), ('전기', 50), ('얼굴', 50), ('이후', 50), ('페이지', 50), ('던데', 49), ('아침', 49), ('예전', 49), ('도대체', 49), ('번호', 49), ('개인', 49), ('가야', 49), ('듣기', 48), ('부모님', 48), ('계산', 48), ('본인', 48), ('신입생', 48), ('답변', 48), ('해결', 48), ('프로젝트', 48), ('금요일', 48), ('기전', 48), ('강의실', 48), ('공대', 47), ('수준', 47), ('기분', 47), ('한국', 47), ('부탁', 47), ('가기', 46), ('평가', 46), ('개월', 46), ('라면', 46), ('잘못', 46), ('연장', 46), ('융사', 46), ('안보', 45), ('안나', 45), ('동의', 45), ('상태', 45), ('결석', 45), ('정리', 45), ('교시', 44), ('러닝', 44), ('세계', 4 ...

# %%
tf_cnt = return_tf(ndf['sen'])
tf_cnt = sorted(tf_cnt.items(), key=lambda x: x[1], reverse=True)
print(tf_cnt)
# Out:
# [('교수', 2747), ('과제', 1715), ('사람', 1624), ('강의', 1587), ('학교', 1542), ('수업', 1183), ('학기', 1054), ('시험', 871), ('진짜', 828), ('학년', 821), ('실험', 767), ('지금', 763), ('인강', 759), ('과목', 679), ('가요', 672), ('질문', 650), ('학점', 623), ('공부', 617), ('오늘', 612), ('대학', 609), ('신청', 595), ('수강신청', 591), ('전공', 559), ('생각', 559), ('그냥', 552), ('추천', 549), ('광운대', 543), ('공지', 481), ('문제', 473), ('수학', 465), ('이해', 460), ('건가', 409), ('중간고사', 404), ('정정', 400), ('제출', 399), ('기간', 380), ('수강', 372), ('레포트', 354), ('물리', 350), ('교재', 342), ('교양', 328), ('동아리', 325), ('영어', 317), ('대면', 317), ('선배', 316), ('등록금', 312), ('개강', 312), ('온라인', 308), ('정도', 306), ('휴학', 306), ('친구', 304), ('도서관', 302), ('하나요', 293), ('신분', 291), ('알바', 290), ('기숙사', 275), ('공학', 273), ('새내기', 266), ('장학금', 261), ('제발', 244), ('관련', 234), ('메일', 234), ('계속', 232), ('에타', 231), ('쪽지', 231), ('내일', 231), ('한번', 230), ('보고', 229), ('생활', 228), ('다시', 228), ('광운', 228), ('요즘', 227), ('아시', 227), ('자료', 223), ('졸업', 220), ('근처', 219), ('노트북', 218), ('이제', 218), ('학생', 215), ('원래', 209), ('연기', 207), ('대체', 205), ('재수강', 201), ('계절', 200), ('남자', 199), ('중간', 197), ('경영', 196), ('성적', 195), ('갑자기', 190), ('청원', 189), ('전정', 187), ('복학', 187), ('시작', 185), ('경영학', 183), ('계획', 183), ('컴공', 182), ('준비', 181), ('학과', 179), ('시간표', 177), ('전자회로', 176), ('주차', 176), ('자취', 175), ('전자기학', 174), ('확인', 174), ('퀴즈', 174), ('보통', 170), ('기초', 167), ('서울', 167), ('사고', 163), ('복전', 162), ('군대', 161), ('취업', 160), ('가능', 160), ('처음', 160), ('토익', 159), ('솔루션', 157), ('때문', 156), ('사진', 154), ('실습', 153), ('내용', 151), ('프로그램', 149), ('학번', 148), ('방법', 147), ('프로그래밍', 145), ('아이패드', 144), ('열람', 144), ('출석', 144), ('사회', 143), ('주변', 142), ('고민', 139), ('인증', 139), ('하루', 139), ('뭔가', 138), ('사용', 137), ('대수', 137), ('소리', 136), ('경제', 133), ('어케', 131), ('족보', 127), ('신문사', 127), ('학부', 127), ('페가수스', 127), ('인간', 126), ('이름', 125), ('여자', 124), ('영상', 122), ('진자', 121), ('해도', 120), ('근로', 120), ('컴퓨터', 120), ('화학', 120), ('회로이론', 120), ('문과', 119), ('문자', 119), ('이유', 119), ('존나', 119), ('인정', 118), ('카페', 115), ('점수', 115), ('국가', 114), ('얘기', 114), ('전략', 113), ('환불', 112), ('운체', 112), ('사항', 111), ('추가', 110), ('처리', 110), ('파일', 110), ('설문조사', 109), ('전과', 108), ('운동', 108), ('문화', 108), ('누가', 107), ('결과', 107), ('사실', 105), ('오류', 105), ('지각', 105), ('인터넷', 104), ('영화', 104), ('취소', 104), ('댓글', 104), ('기준', 102), ('정말', 102), ('연락', 102), ('다운', 101), ('홈페이지', 100), ('이용', 100), ('지원', 100), ('발표', 100), ('게시판', 100), ('유캠', 99), ('부분', 99), ('소프트', 99), ('게임', 99), ('경우', 99), ('전체', 99), ('모바일', 99), ('오프라인', 99), ('노래', 98), ('머리', 98), ('프로', 98), ('작성', 98), ('학습', 98), ('전화', 97), ('현재', 97), ('보신', 96), ('자리', 96), ('구해', 96), ('공수', 95), ('설계', 95), ('연습', 94), ('포기', 94), ('클라스', 93), ('관리', 92), ('가지', 92), ('정보', 92), ('이면', 91), ('상황', 90), ('진행', 89), ('그거', 88), ('필기', 88), ('걱정', 87), ('예술', 87), ('나중', 87), ('그대로', 86), ('선물', 85), ('러닝', 85), ('전기', 85), ('강의실', 85), ('범위', 84), ('포함', 84), ('오픈', 84), ('기말고사', 84), ('융사', 84), ('느낌', 83), ('교시', 83), ('코딩', 83), ('일반', 82), ('저녁', 82), ('헬스장', 82), ('가격', 81), ('반대', 81), ('컴퓨팅', 81), ('신천지', 81), ('연장', 81), ('차이', 80), ('한국', 80), ('예비', 80), ('드랍', 80), ('배속', 80), ('세계', 79), ('증명서', 78), ('저번', 78), ('이메일', 78), ('결석', 78), ('자꾸', 77), ('심리', 77), ('제일', 77), ('미디어', 77), ('방금', 77), ('국장', 76), ('날씨', 76), ('실화', 75), ('별로', 75), ('계산', 75), ('번호', 75), ('만석', 75), ('아예', 74), ('평가', 74), ('새끼', 74), ('디지털', 74), ('방학', 73), ('대한', 73), ('부모님', 72), ('아이폰', 72), ('필수', 72), ('이건', 72), ('프로젝트', 72), ('대해', 71), ('작년', 71), ('말씀', 71), ('올해', 71), ('제대로', 71), ('복수', 71), ('페이지', 71), ('디논', 71), ('서점', 71), ('컴활', 70), ('납부', 70), ('전통', 70), ('회계', 70), ('기업', 70), ('번방', 70), ('미리', 69), ('마케팅', 69), ('벌써', 69), ('형님', 69), ('난이도', 69), ('학우', 69), ('신입생', 69), ('실시간', 69), ('카톡', 68), ('가면', 68), ('모든', 68), ('의견', 68), ('주말', 68), ('융합', 68), ('기전', 68), ('비대', 68), ('관심', 67), ('중도', 67), ( ...

# %%
for i in range(0, 9):
    corpus = []
    for index, row in ndf.iterrows():
        if row['lab'] == i: corpus.append(row['sen'])
    tfidf = return_tfidf(return_tf(corpus), return_df(corpus), len(corpus))
    tfidf = sorted(tfidf.items(), key=lambda x: x[1], reverse=True)
    print( str(i) + "th label")
    cnt = 0
    for item in tfidf:
        if cnt >= 20: break
        print(item)
        cnt += 1
    print(" ")
# Out:
# 0th label
# ('실험', 95.69868699482906)
# ('제출', 94.38022048500738)
# ('청원', 90.95110370943927)
# ('질문', 89.83625952992209)
# ('인강', 88.21604559624467)
# ('이해', 87.86708242794747)
# ('알바', 87.2135578398314)
# ('대면', 82.44318845091368)
# ('동아리', 81.43318905877388)
# ('과목', 79.49274363267652)
# ('학습', 79.06058151650093)
# ('학년', 78.72865566637742)
# ('도서관', 78.57546183003565)
# ('수학', 78.50974914411759)
# ('공지', 78.3034298244019)
# ('토익', 76.67023300391433)
# ('물리', 74.97534448647218)
# ('생각', 74.88773607227617)
# ('기숙사', 74.70432959355755)
# ('온라인', 74.15297141913192)
#
# 1th label
# ('오늘', 141.09866859534765)
# ('추천', 138.97079505706762)
# ('질문', 138.60298296679764)
# ('선물', 120.08542761761028)
# ('교수', 119.23206414464853)
# ('남자', 118.86849761538453)
# ('친구', 118.16134854816355)
# ('페가수스', 106.33126579216422)
# ('노트북', 105.26925834393421)
# ('신문사', 103.63073024154407)
# ('게임', 102.29499389648284)
# ('생각', 101.41466805290611)
# ('기숙사', 98.70899577587596)
# ('족보', 98.47537338042328)
# ('여자', 95.99647138477862)
# ('학교', 93.55131186733962)
# ('아이패드', 91.73004290941161)
# ('문제', 91.6657757465774)
# ('과제', 90.82053661045305)
# ('쪽지', 90.35608016845147)
#
# 2th label
# ('계절', 155.74827888341704)
# ('장학금', 154.60307095045076)
# ('공학', 149.84379351634212)
# ('재수강', 138.57015988892252)
# ('복전', 137.42561429799184)
# ('영어', 135.245546703555)
# ('수학', 133.09134773377477)
# ('실험', 131.09885064440638)
# ('물리', 125.23908139410916)
# ('질문', 124.39295527278914)
# ('경영', 122.67267696191473)
# ('졸업', 121.44236739690864)
# ('복학', 120.55888039465923)
# ('광운대', 119.78891279457727)
# ('인강', 118.23278296149051)
# ('교재', 117.83539735642775)
# ('수강', 117.46928644902255)
# ('시험', 117.18225478222344)
# ('동아리', 116.17307090334847)
# ('학부', 112.07024446623659)
#
# 3th label
# ('오늘', 90.74949838590669)
# ('알바', 90.66114776485239)
# ('추천', 85.40027534540488)
# ('아이패드', 82.92704559644997)
# ('신문사', 78.92891698380848)
# ('지금', 76.13781544229255)
# ('진짜', 74.09642298054396)
# ('사람', 71.53460228832785)
# ('요즘', 70.00840163320824)
# ('생각', 68.78107748888569)
# ('남자', 68.1660752744396)
# ('에타', 68.1660752744396)
# ('진자', 67.74925180845563)
# ('과제', 65.98741409079747)
# ('청원', 64.21581185079036)
# ('여자', 62.639096198133686)
# ('근로', 62.37606383461477)
# ('문제', 61.726738903729284)
# ('저녁', 61.29814922645353)
# ('번방', 61.29814922645353)
#
# 4th label
# ('휴학', 135.04213002900164)
# ('졸업', 120.97130974565076)
# ('토익', 116.13245735582473)
# ('수학', 114.20694034077891)
# ('정정', 112.40458804338593)
# ('대학', 112.1355749118783)
# ('학점', 111.36465361545608)
# ('연기', 107.86211032184674)
# ('학년', 103.9973009812913)
# ('경영학', 103.88192604128153)
# ('자료', 103.22885098295531)
# ('실험', 102.36063213531628)
# ('영어', 102.07692119649283)
# ('등록금', 102.07078264511408)
# ('이해', 98.65928556782245)
# ('질문', 98.38999859312928)
# ('수강', 98.27046523579533)
# ('포기', 97.54984464615617)
# ('제출', 95.13203768140275)
# ('복학', 93.77721989421278)
#
# 5th label
# ('실험', 121.5369015303781)
# ('도서관', 119.22444790307502)
# ('동아리', 118.87801113485928)
# ('시험', 109.8872264813586)
# ('레포트', 106.31593457796885)
# ('광운대', 105.16356226952354)
# ('추천', 103.48686664962888)
# ('질문', 99.91046774471204)
# ('교재', 98.49138664519798)
# ('이해', 98.13309805806354)
# ('공부', 92.56255624893028)
# ('근처', 92.24884791156651)
# ('대면', 91.80844726400221)
# ('수업', 91.16860975378968)
# ('기숙사', 91.15147142016221)
# ('경영학', 90.28510286656348)
# ('과목', 89.55982152451992)
# ('강의', 89.32011712731013)
# ('신청', 86.51950140753586)
# ('대학', 85.99195416996434)
#
# 6th label
# ('동아리', 123.986461825995)
# ('물리', 105.38024712918816)
# ('전자회로', 104.60448265681683)
# ('전공', 102.22302257172227)
# ('전자기학', 99.46000852642479)
# ('광운', 99.13326273707587)
# ('교재', 98.04042364527663)
# ('레포트', 91.99798102921727)
# ('이해', 90.09908837217037)
# ('선배', 89.01750023646586)
# ('회로이론', 88.58973681066503)
# ('전정', 88.26005063981376)
# ('학년', 87.20852592460513)
# ('질문', 86.46905935673337)
# ('솔루션', 86.45555081355549)
# ('추천', 85.96026898076644)
# ('기초', 85.21966253111087)
# ('실험', 84.66970108910897)
# ('사회', 82.73108289349875)
# ('근처', 82.01146505648776)
#
# 7th label
# ('멍청이', 185.95120490191138)
# ('다나', 165.55573982415902)
# ('제출', 124.92583148497964)
# ('시험', 120.68276403186002)
# ('인강', 110.52032467906147)
# ('제발', 107.89834602557532)
# ('수업', 99.48806013514692)
# ('강의', 96.17199583569096)
# ('알바', 95.26765413362385)
# ('문제', 94.38610833334452)
# ('레포트', 93.53555611530106)
# ('학교', 93.11062038289391)
# ('사람', 90.38515755298361)
# ('공부', 90.10357073863216)
# ('교수', 89.1166586531949)
# ('오늘', 88.5745057114569)
# ('요즘', 87.74093686243172)
# ('지금', 84.07285787754286)
# ('기숙사', 81.84366169125468)
# ('청원', 80.87700569236742)
#
# 8th label
# ('도서관', 110.75596344896806)
# ('학교', 105.98553183936572)
# ('시험', 104.82272886800939)
# ('질문', 101.36299137168055)
# ('과제', 99.10965861797173)
# ('기숙사', 99.088905474046)
# ('알바', 98.72628065324037)
# ('교수', 97.03127730849407)
# ('자취', 90.7311057624393)
# ('추천', 88.6543026706126)
# ('진짜', 88.40431727243994)
# ('생각', 88.16495568938387)
# ('오늘', 87.76129429446095)
# ('에타', 87.14464919657412)
# ('친구', 86.25870873712026)
# ('실험', 85.4439335265993)
# ('지금', 84.72002168057143)
# ('이해', 82.2279122575672)
# ('문제', 79.4664878947562)
# ('카드', 77.60802824684254)
